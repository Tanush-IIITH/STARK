# %%
import os
import sys
from benchmark_exact import run_benchmark_on_dataset

# %%
# Configure paths
DATASET_ROOT = "../DnA_dataset/ncbi_dataset/data"  # UPDATE THIS PATH
OUTPUT_ROOT = "results_exact"

# %%
# Get all dataset folders
datasets = sorted([d for d in os.listdir(DATASET_ROOT) 
                   if os.path.isdir(os.path.join(DATASET_ROOT, d))])

print(f"Found {len(datasets)} datasets")
print(f"Processing with Shift-Or exact matching (≤64 bp patterns)...")
# Out:
# Found 90 datasets
# Processing with Shift-Or exact matching (≤64 bp patterns)...

# %%
# Process each dataset
for i, dataset_name in enumerate(datasets, 1):
    dataset_path = os.path.join(DATASET_ROOT, dataset_name)

    # Find .fna file
    fasta_file = None
    for file in os.listdir(dataset_path):
        if file.endswith('.fna') or file.endswith('.fasta'):
            fasta_file = os.path.join(dataset_path, file)
            break

    if not fasta_file:
        print(f"  {i}/{len(datasets)}: Skipping {dataset_name} - No FASTA file")
        continue

    # Run benchmark
    output_dir = os.path.join(OUTPUT_ROOT, dataset_name)
    print(f"\n{i}/{len(datasets)}: {dataset_name}")

    try:
        run_benchmark_on_dataset(fasta_file, output_dir)
    except Exception as e:
        print(f"  ✗ Error: {e}")
        continue
# Out:
# 1/90: GCA_000005845.2
# Processing GCA_000005845.2...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_000005845.2
#
# 2/90: GCA_000269645.2
# Processing GCA_000269645.2...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_000269645.2
#
# 3/90: GCA_000273425.1
# Processing GCA_000273425.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_000273425.1
#
# 4/90: GCA_000364365.1
# Processing GCA_000364365.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_000364365.1
#
# 5/90: GCA_000482265.1
# Processing GCA_000482265.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_000482265.1
#
# 6/90: GCA_000517165.1
# Processing GCA_000517165.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_000517165.1
#
# 7/90: GCA_000801205.1
# Processing GCA_000801205.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_000801205.1
#
# 8/90: GCA_001308065.1
# Processing GCA_001308065.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_001308065.1
#
# 9/90: GCA_001544635.1
# Processing GCA_001544635.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_001544635.1
#
# 10/90: GCA_001566335.1
# Processing GCA_001566335.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_001566335.1
#
# 11/90: GCA_002843685.1
# Processing GCA_002843685.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...
#   ✓ Completed GCA_002843685.1
#
# 12/90: GCA_002966145.1
# Processing GCA_002966145.1...
#   Running scaling benchmark...
#   Running pattern length benchmark...
#   Running multiple patterns benchmark...

# %%
print("\n" + "="*70)
print("✅ EXACT MATCHING BENCHMARKS COMPLETED!")
print(f"Results saved to: {OUTPUT_ROOT}/")
print(f"Total datasets processed: {len([d for d in os.listdir(OUTPUT_ROOT)])} / {len(datasets)}")
print("="*70)
# Out:
# ======================================================================
# ✅ EXACT MATCHING BENCHMARKS COMPLETED!
# Results saved to: results_exact/
# Total datasets processed: 0 / 1
# ======================================================================
