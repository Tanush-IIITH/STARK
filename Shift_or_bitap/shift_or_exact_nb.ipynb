# %%
import os
import sys
from benchmark_exact import run_benchmark_on_dataset

# %%
# Configure paths
DATASET_ROOT = "../DnA_dataset/ncbi_dataset/data"  # UPDATE THIS PATH
OUTPUT_ROOT = "results_exact"

# %%
# Get all dataset folders
datasets = sorted([d for d in os.listdir(DATASET_ROOT) 
                   if os.path.isdir(os.path.join(DATASET_ROOT, d))])

print(f"Found {len(datasets)} datasets")
print(f"Processing with Shift-Or exact matching (≤64 bp patterns)...")
# Out:
# Found 90 datasets
# Processing with Shift-Or exact matching (≤64 bp patterns)...

# %%
# Process each dataset
for i, dataset_name in enumerate(datasets, 1):
    dataset_path = os.path.join(DATASET_ROOT, dataset_name)

    # Find .fna file
    fasta_file = None
    for file in os.listdir(dataset_path):
        if file.endswith('.fna') or file.endswith('.fasta'):
            fasta_file = os.path.join(dataset_path, file)
            break

    if not fasta_file:
        print(f"  {i}/{len(datasets)}: Skipping {dataset_name} - No FASTA file")
        continue

    # Run benchmark
    output_dir = os.path.join(OUTPUT_ROOT, dataset_name)
    print(f"\n{i}/{len(datasets)}: {dataset_name}")

    try:
        run_benchmark_on_dataset(fasta_file, output_dir)
    except Exception as e:
        print(f"  ✗ Error: {e}")
        continue
# Out:
# 1/90: GCA_000005845.2
# Processing GCA_000005845.2...
#   Running scaling benchmark...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 21
#      18 print(f"\n{i}/{len(datasets)}: {dataset_name}")
#      20 try:
# ---> 21     run_benchmark_on_dataset(fasta_file, output_dir)
#      22 except Exception as e:
#      23     print(f"  ✗ Error: {e}")
#
# File ~/Desktop/AAD/STARK/Shift_or_bitap/benchmark_exact.py:332, in run_benchmark_on_dataset(fasta_file, output_dir)
#     330 # 1. Scaling benchmark
#     331 print("  Running scaling benchmark...")
# --> 332 scaling_results = benchmark.benchmark_scaling(text, pattern_length=20, num_runs=3)
#     333 benchmark.save_csv(scaling_results, os.path.join(output_dir, 'scaling_results.csv'))
#     334 benchmark.plot_scaling(scaling_results,
#     335                       os.path.join(output_dir, 'scaling_time_memory.jpg'),
#     336                       dataset_name)
#
# File ~/Desktop/AAD/STARK/Shift_or_bitap/benchmark_exact.py:89, in ShiftOrExactBenchmark.benchmark_scaling(self, text, pattern_length, slice_sizes, num_runs)
#      87 for _ in range(num_runs):
#      88     matcher = ShiftOrExact(pattern)
# ---> 89     _, elapsed, peak_mem = self.measure_time_and_memory(
#      90         matcher.search, text_slice
#      91     )
#      92     times.append(elapsed)
#      93     memories.append(peak_mem)
#
# File ~/Desktop/AAD/STARK/Shift_or_bitap/benchmark_exact.py:44, in ShiftOrExactBenchmark.measure_time_and_memory(self, func, *args, **kwargs)
#      41 tracemalloc.start()
#      42 start_time = time.perf_counter()
# ---> 44 result = func(*args, **kwargs)
#      46 end_time = time.perf_counter()
#      47 current, peak = tracemalloc.get_traced_memory()
#
# File ~/Desktop/AAD/STARK/Shift_or_bitap/shift_or_exact.py:132, in ShiftOrExact.search(self, text)
#     130     if (D & match_bit) == 0:
#     131         match_pos = j - self.pattern_length + 1
# --> 132         matches.append(match_pos)
#     134 return matches
#
# KeyboardInterrupt:

# %%
print("\n" + "="*70)
print("✅ EXACT MATCHING BENCHMARKS COMPLETED!")
print(f"Results saved to: {OUTPUT_ROOT}/")
print(f"Total datasets processed: {len([d for d in os.listdir(OUTPUT_ROOT)])} / {len(datasets)}")
print("="*70)
# Out:
# ======================================================================
# ✅ EXACT MATCHING BENCHMARKS COMPLETED!
# Results saved to: results_exact/
# Total datasets processed: 0 / 1
# ======================================================================
